# %%
import pandas as pd
import cleaning_functions as f
import os

# %% [markdown]
# # 1. Carga de datos **vivienda**

# %%
df_ciudades = pd.read_csv('../files/viviendas_idealista.csv', sep = ";")

# %%
df_ciudades['Regimen'] = 'Compra'

# %%
df_ciudades
# Out:
#                                                Vivienda  Precio  \
# 0                            Piso en San Isidro, Madrid  245000
# 1     Piso en calle de Pablo Montesinos, San Isidro,...  240000
# 2     Piso en calle Soldado José María Rey, San Isid...  199000
# 3            Piso en calle Alcaudón, San Isidro, Madrid  237000
# 4                            Piso en San Isidro, Madrid  250000
# ...                                                 ...     ...
# 5561    Piso en avenida de América, 29, Zaidín, Granada  149900
# 5562        Piso en avenida de América, Zaidín, Granada  149900
# 5563  Dúplex en avenida Salvador Allende, Zaidín, Gr...  210000
# 5564        Piso en avenida de América, Zaidín, Granada  149900
# 5565        Piso en avenida de América, Zaidín, Granada  149900
#
#      Numero habitaciones Metros cuadrados   Ciudad         Zona      Barrio  \
# 0                 2 hab.            65 m²   madrid  carabanchel  san-isidro
# 1                 3 hab.            79 m²   madrid  carabanchel  san-isidro
# 2                 1 hab.            88 m²   madrid  carabanchel  san-isidro
# 3                 3 hab.            67 m²   madrid  carabanchel  san-isidro
# 4                 2 hab.            73 m²   madrid  carabanchel  san-isidro
# ...                  ...              ...      ...          ...         ...
# 5561              3 hab.            65 m²  granada       zaidin      zaidin
# 5562              3 hab.            65 m²  granada       zaidin      zaidin
# 5563              2 hab.            76 m²  granada       zaidin      zaidin
# 5564              3 hab.            65 m²  granada       zaidin      zaidin
# 5565              3 hab.            65 m²  granada       zaidin      zaidin
#
#      Garaje                      Descripcion Regimen
# 0        No  Planta 1ª exterior con ascensor  Compra
# 1        No       Bajo exterior con ascensor  Compra
# 2        No  Planta 2ª exterior con ascensor  Compra
# 3        No  Planta 1ª exterior con ascensor  Compra
# 4        No  Planta 1ª exterior sin ascensor  Compra
# ...     ...                              ...     ...
# 5561     No  Planta 5ª exterior con ascensor  Compra
# 5562     No  Planta 5ª exterior con ascensor  Compra
# 5563     No  Planta 5ª exterior con ascensor  Compra
# 5564     No  Planta 5ª exterior con ascensor  Compra
# 5565     No  Planta 5ª exterior con ascensor  Compra
#
# [5566 rows x 10 columns]

# %%
df_alquiler = pd.read_csv('../files/viviendas_idealista_alquiler.csv', sep =";")

# %%
df_alquiler1 = pd.read_csv('../files/viviendas_idealista_alquiler1.csv', sep =";")

# %%
df_alquiler2 = pd.read_csv('../files/viviendas_idealista_alquiler2.csv', sep =";")

# %%
df_alquiler3 = pd.read_csv('../files/viviendas_idealista_alquiler3.csv', sep =";")

# %%
df_alquiler4 = pd.read_csv('../files/viviendas_idealista_alquiler4.csv', sep =";")

# %%
df_alquiler5 = pd.read_csv('../files/viviendas_idealista_alquiler5.csv', sep =";")

# %%
df_ciudades1 = pd.concat([df_ciudades, df_alquiler, df_alquiler1, df_alquiler2, df_alquiler3, df_alquiler4, df_alquiler5])

# %%
df_ciudades1
# Out:
#                                                Vivienda  Precio  \
# 0                            Piso en San Isidro, Madrid  245000
# 1     Piso en calle de Pablo Montesinos, San Isidro,...  240000
# 2     Piso en calle Soldado José María Rey, San Isid...  199000
# 3            Piso en calle Alcaudón, San Isidro, Madrid  237000
# 4                            Piso en San Isidro, Madrid  250000
# ...                                                 ...     ...
# 1662             Piso en Laos, 5, Emilio Lemos, Sevilla     980
# 1663             Piso en Laos, 5, Emilio Lemos, Sevilla     905
# 1664             Piso en Laos, 5, Emilio Lemos, Sevilla     990
# 1665             Piso en Laos, 5, Emilio Lemos, Sevilla     855
# 1666   Piso en calle Pakistán, 5, Emilio Lemos, Sevilla     750
#
#      Numero habitaciones Metros cuadrados   Ciudad          Zona  \
# 0                 2 hab.            65 m²   madrid   carabanchel
# 1                 3 hab.            79 m²   madrid   carabanchel
# 2                 1 hab.            88 m²   madrid   carabanchel
# 3                 3 hab.            67 m²   madrid   carabanchel
# 4                 2 hab.            73 m²   madrid   carabanchel
# ...                  ...              ...      ...           ...
# 1662              3 hab.            98 m²  sevilla  sevilla-este
# 1663              2 hab.            80 m²  sevilla  sevilla-este
# 1664              3 hab.           100 m²  sevilla  sevilla-este
# 1665              2 hab.            80 m²  sevilla  sevilla-este
# 1666              2 hab.            85 m²  sevilla  sevilla-este
#
#             Barrio           Garaje                      Descripcion   Regimen
# 0       san-isidro               No  Planta 1ª exterior con ascensor    Compra
# 1       san-isidro               No       Bajo exterior con ascensor    Compra
# 2       san-isidro               No  Planta 2ª exterior con ascensor    Compra
# 3       san-isidro               No  Planta 1ª exterior con ascensor    Compra
# 4       san-isidro               No  Planta 1ª exterior sin ascensor    Compra
# ...            ...              ...                              ...       ...
# 1662  emilio-lemos  Garaje incluido       Bajo exterior con ascensor  Alquiler
# 1663  emilio-lemos  Garaje incluido  Planta 1ª exterior con ascensor  Alquiler
# 1664  emilio-lemos  Garaje incluido  Planta 1ª exterior con ascensor  Alquiler
# 1665  emilio-lemos  Garaje incluido       Bajo exterior con ascensor  Alquiler
# 1666  emilio-lemos  Garaje incluido       Bajo interior con ascensor  Alquiler
#
# [9424 rows x 10 columns]

# %%
df_ciudades1
# Out:
#                                                Vivienda  Precio  \
# 0                            Piso en San Isidro, Madrid  245000
# 1     Piso en calle de Pablo Montesinos, San Isidro,...  240000
# 2     Piso en calle Soldado José María Rey, San Isid...  199000
# 3            Piso en calle Alcaudón, San Isidro, Madrid  237000
# 4                            Piso en San Isidro, Madrid  250000
# ...                                                 ...     ...
# 1662             Piso en Laos, 5, Emilio Lemos, Sevilla     980
# 1663             Piso en Laos, 5, Emilio Lemos, Sevilla     905
# 1664             Piso en Laos, 5, Emilio Lemos, Sevilla     990
# 1665             Piso en Laos, 5, Emilio Lemos, Sevilla     855
# 1666   Piso en calle Pakistán, 5, Emilio Lemos, Sevilla     750
#
#      Numero habitaciones Metros cuadrados   Ciudad          Zona  \
# 0                 2 hab.            65 m²   madrid   carabanchel
# 1                 3 hab.            79 m²   madrid   carabanchel
# 2                 1 hab.            88 m²   madrid   carabanchel
# 3                 3 hab.            67 m²   madrid   carabanchel
# 4                 2 hab.            73 m²   madrid   carabanchel
# ...                  ...              ...      ...           ...
# 1662              3 hab.            98 m²  sevilla  sevilla-este
# 1663              2 hab.            80 m²  sevilla  sevilla-este
# 1664              3 hab.           100 m²  sevilla  sevilla-este
# 1665              2 hab.            80 m²  sevilla  sevilla-este
# 1666              2 hab.            85 m²  sevilla  sevilla-este
#
#             Barrio           Garaje                      Descripcion   Regimen
# 0       san-isidro               No  Planta 1ª exterior con ascensor    Compra
# 1       san-isidro               No       Bajo exterior con ascensor    Compra
# 2       san-isidro               No  Planta 2ª exterior con ascensor    Compra
# 3       san-isidro               No  Planta 1ª exterior con ascensor    Compra
# 4       san-isidro               No  Planta 1ª exterior sin ascensor    Compra
# ...            ...              ...                              ...       ...
# 1662  emilio-lemos  Garaje incluido       Bajo exterior con ascensor  Alquiler
# 1663  emilio-lemos  Garaje incluido  Planta 1ª exterior con ascensor  Alquiler
# 1664  emilio-lemos  Garaje incluido  Planta 1ª exterior con ascensor  Alquiler
# 1665  emilio-lemos  Garaje incluido       Bajo exterior con ascensor  Alquiler
# 1666  emilio-lemos  Garaje incluido       Bajo interior con ascensor  Alquiler
#
# [9424 rows x 10 columns]

# %%
df_ciudades1['Garaje'].value_counts()
# Out:
# Garaje
# No                       6324
# Garaje incluido          2669
# Garaje opc. 100 €/mes      69
# Garaje opc. 20.000 €       39
# Garaje opc. 30.000 €       29
#                          ...
# Garaje opc. 17.000 €        1
# Garaje opc. 15 €            1
# Garaje opc. 12.000 €        1
# Garaje opc. 26.000 €        1
# Garaje opc. 450 €/mes       1
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# ## Limpiar las columnas `Ciudad`, `Zona` y `Barrio`

# %%
df_ciudades1 = f.limpiar_localizaciones(df_ciudades1)

# %%
df_ciudades1.columns
# Out:
# Index(['Vivienda', 'Precio', 'Numero habitaciones', 'Metros cuadrados',
#        'Ciudad', 'Zona', 'Barrio', 'Garaje', 'Descripcion', 'Regimen'],
#       dtype='object')

# %%
df_ciudades1 = f.cambiar_nombre_columnas(df_ciudades1)

# %%
df_ciudades1.columns
# Out:
# Index(['Vivienda', 'Precio (€)', 'Numero habitaciones',
#        'Metros cuadrados (m²)', 'Ciudad', 'Zona', 'Barrio', 'Garaje',
#        'Descripcion', 'Regimen'],
#       dtype='object')

# %%
df_ciudades1['Numero habitaciones'].unique()
# Out:
# array(['2 hab.', '3 hab.', '1 hab.', '4 hab.', 'no definido', '6 hab.',
#        '5 hab.', '7 hab.', '8 hab.', '9 hab.', '10 hab.', '11 hab.',
#        '12 hab.', '24 hab.', '21 hab.', '14 hab.', '18 hab.', '16 hab.',
#        '20 hab.', '40 hab.', '13 hab.'], dtype=object)

# %%
df_ciudades1['Numero habitaciones'].value_counts()
# Out:
# Numero habitaciones
# 3 hab.         3628
# 2 hab.         2710
# 4 hab.         1210
# 1 hab.         1136
# no definido     261
# 5 hab.          260
# 6 hab.           89
# 9 hab.           41
# 7 hab.           29
# 8 hab.           19
# 10 hab.          10
# 14 hab.           7
# 12 hab.           5
# 20 hab.           5
# 13 hab.           4
# 16 hab.           3
# 11 hab.           2
# 18 hab.           2
# 24 hab.           1
# 21 hab.           1
# 40 hab.           1
# Name: count, dtype: int64

# %%
df_ciudades1[df_ciudades1['Numero habitaciones']=='no definido']
# Out:
#                                                Vivienda  Precio (€)  \
# 34    Estudio en calle Nuestra Señora de la Esperanz...      163000
# 156           Ático en Dátil, 21, Puerta Bonita, Madrid      237896
# 158           Ático en Dátil, 21, Puerta Bonita, Madrid      241532
# 195   Estudio en calle de Pedro Domingo, Puerta Boni...      107000
# 201   Estudio en paseo Castellanos, Puerta Bonita, M...      144000
# ...                                                 ...         ...
# 1624  Estudio en avenida Alcalde Luis Uruñuela, Alca...         550
# 1627  Estudio en avenida Alcalde Luis Uruñuela, Alca...         600
# 1633  Estudio en avenida Alcalde Luis Uruñuela, Alca...         550
# 1634  Estudio en avenida Alcalde Luis Uruñuela, Alca...         550
# 1642  Estudio en administrador Gutiérrez Anaya, 5, A...         550
#
#      Numero habitaciones Metros cuadrados (m²)   Ciudad          Zona  \
# 34           no definido                 47 m²   Madrid   Carabanchel
# 156          no definido                 45 m²   Madrid   Carabanchel
# 158          no definido                 46 m²   Madrid   Carabanchel
# 195          no definido                 34 m²   Madrid   Carabanchel
# 201          no definido                 73 m²   Madrid   Carabanchel
# ...                  ...                   ...      ...           ...
# 1624         no definido                 40 m²  Sevilla  Sevilla Este
# 1627         no definido                 40 m²  Sevilla  Sevilla Este
# 1633         no definido                 35 m²  Sevilla  Sevilla Este
# 1634         no definido                 40 m²  Sevilla  Sevilla Este
# 1642         no definido                 32 m²  Sevilla  Sevilla Este
#
#                                        Barrio           Garaje  \
# 34                                 San Isidro               No
# 156                             Puerta Bonita               No
# 158                             Puerta Bonita               No
# 195                             Puerta Bonita               No
# 201                             Puerta Bonita               No
# ...                                       ...              ...
# 1624  Alcalde L Urunuela Palacio De Congresos  Garaje incluido
# 1627  Alcalde L Urunuela Palacio De Congresos  Garaje incluido
# 1633  Alcalde L Urunuela Palacio De Congresos  Garaje incluido
# 1634  Alcalde L Urunuela Palacio De Congresos  Garaje incluido
# 1642  Alcalde L Urunuela Palacio De Congresos               No
#
#                           Descripcion   Regimen
# 34    Planta 2ª exterior con ascensor    Compra
# 156   Planta 4ª exterior con ascensor    Compra
# 158   Planta 4ª exterior con ascensor    Compra
# 195        Bajo interior sin ascensor    Compra
# 201                        Planta 5ª     Compra
# ...                               ...       ...
# 1624  Planta 4ª exterior con ascensor  Alquiler
# 1627  Planta 3ª exterior con ascensor  Alquiler
# 1633  Planta 3ª exterior con ascensor  Alquiler
# 1634  Planta 2ª exterior con ascensor  Alquiler
# 1642  Planta 1ª exterior con ascensor  Alquiler
#
# [261 rows x 10 columns]

# %%
df_ciudades1 = f.division_descripcion(df_ciudades1)
# Out:
# c:\Users\Carlota\OneDrive\Escritorio\Proyect-1\src\cleaning_functions.py:43: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Indeterminado' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[no_tiene_mask, ['Planta', 'Interior/Exterior', 'Ascensor']] = 'Indeterminado'

# %%
df_ciudades1['Metros cuadrados (m²)'].str.strip()
# Out:
# 0        65 m²
# 1        79 m²
# 2        88 m²
# 3        67 m²
# 4        73 m²
#          ...
# 1662     98 m²
# 1663     80 m²
# 1664    100 m²
# 1665     80 m²
# 1666     85 m²
# Name: Metros cuadrados (m²), Length: 9424, dtype: object

# %%
df_ciudades1 = f.limpiar_num(df_ciudades1)

# %%
df_ciudades1['Metros cuadrados (m²)'].unique()
# Out:
# array([ 65.   ,  79.   ,  88.   ,  67.   ,  73.   , 107.   ,  60.   ,
#        109.   , 117.   ,  58.   , 120.   , 105.   , 112.   ,  56.   ,
#        140.   , 106.   , 270.   , 407.   ,  87.   , 104.   ,  57.   ,
#        100.   ,  71.   ,  47.   ,  53.   ,  74.   , 130.   ,  84.   ,
#         54.   ,  72.   ,  91.   ,  70.   ,  55.   , 113.   ,  68.   ,
#        103.   ,  90.   ,  95.   ,  75.   ,  80.   ,  78.   ,  85.   ,
#         99.   , 272.   , 132.   , 111.   , 200.   ,  40.   ,  98.   ,
#         69.   ,  52.   , 178.   ,  89.   ,  66.   ,  86.   ,  44.   ,
#         94.   ,  77.   , 210.   , 136.   , 101.   ,  83.   ,  30.   ,
#         64.   , 127.   , 102.   , 171.   , 149.   , 121.   ,  92.   ,
#         97.   ,  45.   ,  61.   ,  46.   ,  63.   ,  62.   , 115.   ,
#         50.   ,  59.   ,  34.   , 144.   ,  27.   , 219.   ,  82.   ,
#         96.   ,  43.   ,  76.   , 110.   , 153.   , 337.   , 119.   ,
#        170.   ,  51.   ,  35.   , 164.   ,  48.   ,  93.   , 150.   ,
#        139.   , 205.   ,  49.   ,  25.   ,  81.   ,  38.   ,  39.   ,
#        135.   , 126.   , 122.   ,  28.   , 287.   , 129.   , 226.   ,
#        253.   , 283.   , 197.   , 175.   , 243.   , 213.   , 220.   ,
#        174.   , 441.   , 222.   , 185.   , 191.   , 189.   , 116.   ,
#        167.   , 228.   , 229.   , 199.   , 187.   , 246.   , 161.   ,
#        302.   , 221.   , 181.   , 147.   , 165.   , 180.   , 215.   ,
#        275.   , 138.   , 356.   , 214.   , 409.   , 700.   , 227.   ,
#        141.   , 182.   , 142.   , 131.   , 195.   , 224.   , 239.   ,
#        183.   , 202.   , 155.   , 248.   , 156.   , 134.   , 169.   ,
#        124.   , 254.   , 290.   , 269.   , 133.   , 163.   , 154.   ,
#        232.   , 218.   , 273.   , 172.   , 256.   , 176.   , 159.   ,
#        137.   , 265.   , 300.   ,  33.   , 128.   , 166.   , 293.   ,
#        259.   , 168.   , 151.   , 162.   , 123.   , 160.   , 204.   ,
#        284.   , 350.   , 328.   , 145.   , 282.   , 334.   , 203.   ,
#        108.   , 206.   , 125.   , 212.   ,  41.   , 190.   , 470.   ,
#        515.   , 194.   , 240.   , 118.   , 295.   , 268.   , 158.   ,
#        177.   , 114.   , 299.   , 157.   , 249.   , 143.   , 420.   ,
#        421.   , 250.   , 236.   , 207.   , 184.   , 173.   , 186.   ,
#        280.   , 370.   , 230.   ,  19.   ,   1.271, 148.   , 353.   ,
#        277.   , 575.   , 252.   , 146.   , 192.   , 152.   , 193.   ,
#        225.   , 376.   , 255.   , 234.   , 548.   , 294.   , 235.   ,
#        209.   , 238.   , 241.   , 310.   , 308.   , 330.   , 201.   ,
#        264.   , 380.   , 414.   , 392.   , 211.   , 453.   ,  23.   ,
#        179.   , 257.   , 408.   , 198.   , 357.   , 331.   , 510.   ,
#          1.48 , 233.   , 542.   , 500.   ,   1.735, 850.   , 842.   ,
#        378.   , 953.   , 650.   ,   1.205, 463.   , 643.   , 679.   ,
#        488.   , 612.   , 508.   , 498.   , 298.   , 347.   , 503.   ,
#        292.   , 260.   , 396.   , 374.   , 332.   ,   1.1  , 501.   ,
#        490.   , 335.   , 580.   , 400.   , 360.   , 604.   , 620.   ,
#        908.   , 406.   , 506.   , 600.   , 690.   , 638.   ,   1.126,
#        464.   , 530.   , 188.   , 451.   , 461.   , 342.   , 550.   ,
#        390.   , 349.   , 285.   , 622.   , 317.   , 546.   ,  26.   ,
#        217.   ,  37.   , 208.   ,  42.   , 262.   , 312.   , 315.   ,
#        388.   , 307.   , 375.   , 320.   , 435.   , 429.   , 583.   ,
#        267.   , 223.   , 524.   , 426.   , 297.   , 291.   ,   1.6  ,
#        261.   , 800.   , 288.   ,   1.   ,   1.7  ,  27.789,   4.   ,
#        468.   , 289.   , 430.   , 433.   , 446.   , 355.   , 531.   ,
#        286.   ,  36.   ,  22.   , 425.   , 258.   ,  24.   , 576.   ,
#         29.   ,  32.   , 555.   ,  31.   ,  16.   ])

# %%
df_ciudades1 = f.no_definido_habitaciones(df_ciudades1)

# %%
df_ciudades1['Numero habitaciones'].value_counts()
# Out:
# Numero habitaciones
# 3     3628
# 2     2710
# 4     1210
# 1     1136
# 5      260
# 2      173
# 6       89
# 9       41
# 3       38
# 1       33
# 7       29
# 8       19
# 4       11
# 10      10
# 14       7
# 5        6
# 12       5
# 20       5
# 13       4
# 16       3
# 11       2
# 18       2
# 24       1
# 21       1
# 40       1
# Name: count, dtype: int64

# %%
df_ciudades1['Regimen'].unique()
# Out:
# array(['Compra', 'Alquiler'], dtype=object)

# %%
df_ciudades1['Regimen'].value_counts()
# Out:
# Regimen
# Compra      5566
# Alquiler    3858
# Name: count, dtype: int64

# %% [markdown]
# ## Eliminar duplicados

# %%
df_ciudades1.duplicated().sum()
# Out:
# 3251

# %%
df_ciudades1[df_ciudades1.duplicated()]
# Out:
#                                               Vivienda  Precio (€)  \
# 18    Piso en calle Paulina Odiaga, San Isidro, Madrid      220000
# 26      Piso en alto de San Isidro, San Isidro, Madrid      450000
# 28       Piso en calle de Peñafiel, San Isidro, Madrid      350000
# 29       Piso en calle de Peñafiel, San Isidro, Madrid      350000
# 60       Ático en calle Rascón, 33, San Isidro, Madrid      409000
# ...                                                ...         ...
# 1662            Piso en Laos, 5, Emilio Lemos, Sevilla         980
# 1663            Piso en Laos, 5, Emilio Lemos, Sevilla         905
# 1664            Piso en Laos, 5, Emilio Lemos, Sevilla         990
# 1665            Piso en Laos, 5, Emilio Lemos, Sevilla         855
# 1666  Piso en calle Pakistán, 5, Emilio Lemos, Sevilla         750
#
#      Numero habitaciones  Metros cuadrados (m²)   Ciudad          Zona  \
# 18                     2                   60.0   Madrid   Carabanchel
# 26                     3                  140.0   Madrid   Carabanchel
# 28                     3                  106.0   Madrid   Carabanchel
# 29                     3                  106.0   Madrid   Carabanchel
# 60                     2                   95.0   Madrid   Carabanchel
# ...                  ...                    ...      ...           ...
# 1662                   3                   98.0  Sevilla  Sevilla Este
# 1663                   2                   80.0  Sevilla  Sevilla Este
# 1664                   3                  100.0  Sevilla  Sevilla Este
# 1665                   2                   80.0  Sevilla  Sevilla Este
# 1666                   2                   85.0  Sevilla  Sevilla Este
#
#             Barrio           Garaje                      Descripcion  \
# 18      San Isidro               No  Planta 2ª exterior sin ascensor
# 26      San Isidro  Garaje incluido  Planta 3ª exterior con ascensor
# 28      San Isidro               No  Planta 1ª exterior sin ascensor
# 29      San Isidro               No  Planta 1ª exterior sin ascensor
# 60      San Isidro  Garaje incluido  Planta 4ª exterior con ascensor
# ...            ...              ...                              ...
# 1662  Emilio Lemos  Garaje incluido       Bajo exterior con ascensor
# 1663  Emilio Lemos  Garaje incluido  Planta 1ª exterior con ascensor
# 1664  Emilio Lemos  Garaje incluido  Planta 1ª exterior con ascensor
# 1665  Emilio Lemos  Garaje incluido       Bajo exterior con ascensor
# 1666  Emilio Lemos  Garaje incluido       Bajo interior con ascensor
#
#        Regimen Planta Interior/Exterior Ascensor
# 18      Compra     2ª          Exterior       No
# 26      Compra     3ª          Exterior       Si
# 28      Compra     1ª          Exterior       No
# 29      Compra     1ª          Exterior       No
# 60      Compra     4ª          Exterior       Si
# ...        ...    ...               ...      ...
# 1662  Alquiler   Bajo          Exterior       Si
# 1663  Alquiler     1ª          Exterior       Si
# 1664  Alquiler     1ª          Exterior       Si
# 1665  Alquiler   Bajo          Exterior       Si
# 1666  Alquiler   Bajo          Interior       Si
#
# [3251 rows x 13 columns]

# %%
df_ciudades1 = df_ciudades1.drop_duplicates()

# %%
df_ciudades1[df_ciudades1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Vivienda, Precio (€), Numero habitaciones, Metros cuadrados (m²), Ciudad, Zona, Barrio, Garaje, Descripcion, Regimen, Planta, Interior/Exterior, Ascensor]
# Index: []

# %%
df_ciudades1
# Out:
#                                                Vivienda  Precio (€)  \
# 0                            Piso en San Isidro, Madrid      245000
# 1     Piso en calle de Pablo Montesinos, San Isidro,...      240000
# 2     Piso en calle Soldado José María Rey, San Isid...      199000
# 3            Piso en calle Alcaudón, San Isidro, Madrid      237000
# 4                            Piso en San Isidro, Madrid      250000
# ...                                                 ...         ...
# 1644             Piso en Laos, 5, Emilio Lemos, Sevilla         980
# 1645             Piso en Laos, 5, Emilio Lemos, Sevilla         905
# 1646             Piso en Laos, 5, Emilio Lemos, Sevilla         990
# 1647             Piso en Laos, 5, Emilio Lemos, Sevilla         855
# 1648   Piso en calle Pakistán, 5, Emilio Lemos, Sevilla         750
#
#      Numero habitaciones  Metros cuadrados (m²)   Ciudad          Zona  \
# 0                      2                   65.0   Madrid   Carabanchel
# 1                      3                   79.0   Madrid   Carabanchel
# 2                      1                   88.0   Madrid   Carabanchel
# 3                      3                   67.0   Madrid   Carabanchel
# 4                      2                   73.0   Madrid   Carabanchel
# ...                  ...                    ...      ...           ...
# 1644                   3                   98.0  Sevilla  Sevilla Este
# 1645                   2                   80.0  Sevilla  Sevilla Este
# 1646                   3                  100.0  Sevilla  Sevilla Este
# 1647                   2                   80.0  Sevilla  Sevilla Este
# 1648                   2                   85.0  Sevilla  Sevilla Este
#
#             Barrio           Garaje                      Descripcion  \
# 0       San Isidro               No  Planta 1ª exterior con ascensor
# 1       San Isidro               No       Bajo exterior con ascensor
# 2       San Isidro               No  Planta 2ª exterior con ascensor
# 3       San Isidro               No  Planta 1ª exterior con ascensor
# 4       San Isidro               No  Planta 1ª exterior sin ascensor
# ...            ...              ...                              ...
# 1644  Emilio Lemos  Garaje incluido       Bajo exterior con ascensor
# 1645  Emilio Lemos  Garaje incluido  Planta 1ª exterior con ascensor
# 1646  Emilio Lemos  Garaje incluido  Planta 1ª exterior con ascensor
# 1647  Emilio Lemos  Garaje incluido       Bajo exterior con ascensor
# 1648  Emilio Lemos  Garaje incluido       Bajo interior con ascensor
#
#        Regimen Planta Interior/Exterior Ascensor
# 0       Compra     1ª          Exterior       Si
# 1       Compra   Bajo          Exterior       Si
# 2       Compra     2ª          Exterior       Si
# 3       Compra     1ª          Exterior       Si
# 4       Compra     1ª          Exterior       No
# ...        ...    ...               ...      ...
# 1644  Alquiler   Bajo          Exterior       Si
# 1645  Alquiler     1ª          Exterior       Si
# 1646  Alquiler     1ª          Exterior       Si
# 1647  Alquiler   Bajo          Exterior       Si
# 1648  Alquiler   Bajo          Interior       Si
#
# [6173 rows x 13 columns]

# %% [markdown]
# ## Unificar el nombre de la ciudad

# %%
ciudades_df = list(set(df_ciudades1['Ciudad'].to_list()))

# %%
municipios_top_20 = ["Madrid", "Barcelona", "Valencia", "Sevilla", "Zaragoza", "Málaga", "Murcia", "Palma", "Las Palmas de Gran Canaria", "Alacant/Alicante","Bilbao", "Córdoba", "Valladolid", "Vigo","L´Hospitalet de Llobregat","Gijón", "Vitoria-Gasteiz", "A Coruña", "Elche/Elx", "Granada"]

# %%
f.comprobar(df_ciudades1)
# Out:
# Cordoba
# Gijon
# Palma De Mallorca
# Alicante Alacant
# A Coruna
# Las Palmas De Gran Canaria
# Elche Elx
# Hospitalet De Llobregat
# Vitoria Gasteiz
# Malaga

# %%
df_ciudades1 = f.unificar_ciudades(df_ciudades1)

# %%
f.comprobar(df_ciudades1)

# %%
df_ciudades1.columns
# Out:
# Index(['Vivienda', 'Precio (€)', 'Numero habitaciones',
#        'Metros cuadrados (m²)', 'Ciudad', 'Zona', 'Barrio', 'Garaje',
#        'Descripcion', 'Regimen', 'Planta', 'Interior/Exterior', 'Ascensor'],
#       dtype='object')

# %%
df_ciudades1.rename(columns={'Ciudad':'Municipio'}, inplace= True)

# %%
df_ciudades1.columns
# Out:
# Index(['Vivienda', 'Precio (€)', 'Numero habitaciones',
#        'Metros cuadrados (m²)', 'Municipio', 'Zona', 'Barrio', 'Garaje',
#        'Descripcion', 'Regimen', 'Planta', 'Interior/Exterior', 'Ascensor'],
#       dtype='object')

# %% [markdown]
# ## Datos nulos

# %%
df_ciudades1.isnull().sum() # no hay valores vacios
# Out:
# Vivienda                 0
# Precio (€)               0
# Numero habitaciones      0
# Metros cuadrados (m²)    0
# Municipio                0
# Zona                     0
# Barrio                   0
# Garaje                   0
# Descripcion              0
# Regimen                  0
# Planta                   0
# Interior/Exterior        0
# Ascensor                 0
# dtype: int64

# %% [markdown]
# Eliminar columna descripcion

# %%
df_ciudades1.drop(columns="Descripcion", inplace=True)

# %%
df_ciudades1
# Out:
#                                                Vivienda  Precio (€)  \
# 0                            Piso en San Isidro, Madrid      245000
# 1     Piso en calle de Pablo Montesinos, San Isidro,...      240000
# 2     Piso en calle Soldado José María Rey, San Isid...      199000
# 3            Piso en calle Alcaudón, San Isidro, Madrid      237000
# 4                            Piso en San Isidro, Madrid      250000
# ...                                                 ...         ...
# 1644             Piso en Laos, 5, Emilio Lemos, Sevilla         980
# 1645             Piso en Laos, 5, Emilio Lemos, Sevilla         905
# 1646             Piso en Laos, 5, Emilio Lemos, Sevilla         990
# 1647             Piso en Laos, 5, Emilio Lemos, Sevilla         855
# 1648   Piso en calle Pakistán, 5, Emilio Lemos, Sevilla         750
#
#      Numero habitaciones  Metros cuadrados (m²) Municipio          Zona  \
# 0                      2                   65.0    Madrid   Carabanchel
# 1                      3                   79.0    Madrid   Carabanchel
# 2                      1                   88.0    Madrid   Carabanchel
# 3                      3                   67.0    Madrid   Carabanchel
# 4                      2                   73.0    Madrid   Carabanchel
# ...                  ...                    ...       ...           ...
# 1644                   3                   98.0   Sevilla  Sevilla Este
# 1645                   2                   80.0   Sevilla  Sevilla Este
# 1646                   3                  100.0   Sevilla  Sevilla Este
# 1647                   2                   80.0   Sevilla  Sevilla Este
# 1648                   2                   85.0   Sevilla  Sevilla Este
#
#             Barrio           Garaje   Regimen Planta Interior/Exterior  \
# 0       San Isidro               No    Compra     1ª          Exterior
# 1       San Isidro               No    Compra   Bajo          Exterior
# 2       San Isidro               No    Compra     2ª          Exterior
# 3       San Isidro               No    Compra     1ª          Exterior
# 4       San Isidro               No    Compra     1ª          Exterior
# ...            ...              ...       ...    ...               ...
# 1644  Emilio Lemos  Garaje incluido  Alquiler   Bajo          Exterior
# 1645  Emilio Lemos  Garaje incluido  Alquiler     1ª          Exterior
# 1646  Emilio Lemos  Garaje incluido  Alquiler     1ª          Exterior
# 1647  Emilio Lemos  Garaje incluido  Alquiler   Bajo          Exterior
# 1648  Emilio Lemos  Garaje incluido  Alquiler   Bajo          Interior
#
#      Ascensor
# 0          Si
# 1          Si
# 2          Si
# 3          Si
# 4          No
# ...       ...
# 1644       Si
# 1645       Si
# 1646       Si
# 1647       Si
# 1648       Si
#
# [6173 rows x 12 columns]

# %% [markdown]
# # 2. Añadir datos adicionales

# %% [markdown]
# ### 2.1 Afiliados **Seguridad Social**

# %%
df_afiliados = pd.read_csv("files/datos_para_almacenar/Afiliados.csv", sep=";")

# %%
df_afiliados = df_afiliados.drop(columns="Unnamed: 0")

# %%
df_afiliados
# Out:
#                      Municipio  reg_autonomos  reg_general    total
# 0              Vitoria-Gasteiz          12556       113431   128182
# 1             Alacant/Alicante          21904       194761   220393
# 2                    Elche/Elx          16002        68998    87780
# 3                        Palma          31272       237944   274052
# 4                    Barcelona         128665      1071264  1227111
# 5    L´Hospitalet de Llobregat          13046        92373   106346
# 6                      Córdoba          19680       120721   145002
# 7                     A Coruña          15352       129757   149457
# 8                      Granada          16592       123937   145124
# 9                       Madrid         203442      2065860  2338583
# 10                      Málaga          37152       289323   333024
# 11                      Murcia          30877       201907   245133
# 12                       Gijón          16142        65407    84221
# 13  Las Palmas de Gran Canaria          22047       177695   206098
# 14                        Vigo          18252       120631   143920
# 15                     Sevilla          38779       355465   404333
# 16                    Valencia          60581       377161   453882
# 17                  Valladolid          15948       137483   156554
# 18                      Bilbao          21921       164290   193218
# 19                    Zaragoza          38941       274477   321363

# %% [markdown]
# ### 2.2 Años de construccion de las viviendas

# %%
df_anos = pd.read_csv("files/datos_para_almacenar/construccion.csv", sep=";")

# %%
df_anos = df_anos.drop(columns="Unnamed: 0")

# %%
def comprobar_municipio(df_ciudades1): 
    ciudades_df = list(set(df_ciudades1['Municipio'].to_list()))

    for ciu in ciudades_df: 
        
        if ciu not in municipios_top_20: 
            print(ciu)

# %%
comprobar_municipio(df_anos)

# %%
df_anos
# Out:
#     Total viviendas en municipio  Total Antes de 1900  Total De 1900 a 1920  \
# 0                         187658                  350                  1752
# 1                         808751                35051                 75201
# 2                         165685                 3882                  8025
# 3                         136205                 1636                  2530
# 4                         155400                    6                   819
# 5                         116080                  169                  1831
# 6                         148955                 1805                  2071
# 7                         141257                  465                  4588
# 8                         110488                   98                  1016
# 9                        1533221                16328                 74456
# 10                        219740                  155                  1771
# 11                        261857                 2091                  2645
# 12                        186482                 3858                  7836
# 13                        175181                  536                  2422
# 14                        327393                  242                  5411
# 15                        159363                  802                  2097
# 16                        414988                 5342                 12000
# 17                        144293                  843                  5620
# 18                        119853                 1043                   852
# 19                        338961                  965                  3227
#
#     Total De 1921 a 1940  Total De 1941 a 1950  Total De 2011 a 2020  \
# 0                   3098                  2582                  3395
# 1                  85023                 23495                 11007
# 2                   9342                  7491                  4994
# 3                   5276                  3534                  3072
# 4                   1792                  3875                  6008
# 5                   1903                  1520                  3140
# 6                   1845                  1417                  4255
# 7                   2640                  2475                  3083
# 8                   3786                  1964                  2907
# 9                  93505                 56596                 46484
# 10                  3707                  5924                  5463
# 11                  3381                  3505                  6349
# 12                  9238                  6420                  4349
# 13                  5360                  4824                  1432
# 14                 10937                  7737                  8620
# 15                  2237                  2534                  2185
# 16                 23584                 11660                  5024
# 17                  5085                  5394                  2407
# 18                   998                  1793                  7273
# 19                 11897                  9268                 12075
#
#     Total No consta  Vivienda principal Total  Vivienda no principal Total  \
# 0              2703                    135864                        51794
# 1             14183                    671177                       137574
# 2                 0                    149461                        16224
# 3               347                    104637                        31568
# 4               683                    122668                        32732
# 5               420                     88498                        27582
# 6              1864                    120349                        28606
# 7              1318                     98316                        42941
# 8               452                    101809                         8679
# 9              7079                   1322855                       210366
# 10            13937                    163570                        56170
# 11             6186                    218245                        43612
# 12             5693                    157101                        29381
# 13             8529                    143195                        31986
# 14             2447                    266588                        60805
# 15              279                    127185                        32178
# 16             2237                    323171                        91817
# 17             2295                    114082                        30211
# 18                0                    107165                        12688
# 19             6588                    280054                        58907
#
#     Total De 1951 a 1970  Total De 1971 a 1990  Total De 1991 a 2010  \
# 0                  57540                 60375                 55863
# 1                 280748                205859                 78184
# 2                  72150                 37791                 22010
# 3                  39204                 42141                 38465
# 4                  41797                 53800                 46620
# 5                  24553                 41432                 41112
# 6                  47333                 46569                 41796
# 7                  34872                 59137                 32679
# 8                  53403                 36413                 10449
# 9                 544841                363724                330208
# 10                 38314                 54387                 96082
# 11                 58536                102094                 77070
# 12                 46347                 58055                 44686
# 13                 49510                 53839                 48729
# 14                 93714                124404                 73881
# 15                 53527                 52681                 43021
# 16                132432                140102                 82607
# 17                 30190                 48890                 43569
# 18                 29037                 42025                 36832
# 19                 97331                108966                 88644
#
#                      Municipio
# 0             Alacant/Alicante
# 1                    Barcelona
# 2                       Bilbao
# 3                     A Coruña
# 4                      Córdoba
# 5                    Elche/Elx
# 6                        Gijón
# 7                      Granada
# 8    L´Hospitalet de Llobregat
# 9                       Madrid
# 10                      Murcia
# 11                      Málaga
# 12                       Palma
# 13  Las Palmas de Gran Canaria
# 14                     Sevilla
# 15                  Valladolid
# 16                    Valencia
# 17                        Vigo
# 18             Vitoria-Gasteiz
# 19                    Zaragoza

# %% [markdown]
# ### 2.3 m2_poblacion_municipio

# %%
df_m2_municipio = pd.read_csv("../src/files/datos_para_almacenar/m2_poblacion_municipio.csv", sep =";")

# %%
df_m2_municipio.columns
set(df_m2_municipio['Municipio'].to_list())
# Out:
# {'A Coruña',
#  'Alacant/Alicante',
#  'Barcelona',
#  'Bilbao',
#  'Córdoba',
#  'Elche/Elx',
#  'Gijón',
#  'Granada',
#  'Las Palmas de Gran Canaria',
#  'L´Hospitalet de Llobregat',
#  'Madrid',
#  'Murcia',
#  'Málaga',
#  'Palma',
#  'Sevilla',
#  'Valencia',
#  'Valladolid',
#  'Vigo',
#  'Vitoria-Gasteiz',
#  'Zaragoza'}

# %%
f.comprobar_municipio(df_m2_municipio)

# %%
df_m2_municipio = df_m2_municipio.drop(["Unnamed: 0"], axis=1)

# %%
df_m2_municipio
# Out:
#                      Municipio  Población  m2_municipio
# 0              Vitoria-Gasteiz    238.247       277.000
# 1             Alacant/Alicante    334.418       201.000
# 2                    Elche/Elx    230.822       326.000
# 3                        Palma    404.681       209.000
# 4                    Barcelona  1.619.337        98.000
# 5    L´Hospitalet de Llobregat    258.642        14.000
# 6                      Córdoba    328.547         1.255
# 7                     A Coruña    246.047        38.000
# 8                      Granada    239.154        88.000
# 9                       Madrid  3.273.049       606.000
# 10                      Málaga    568.507       395.000
# 11                      Murcia    441.345       886.000
# 12                       Gijón    277.198       182.000
# 13  Las Palmas de Gran Canaria    383.308       101.000
# 14                        Vigo    297.124       109.000
# 15                     Sevilla    704.198       141.000
# 16                    Valencia    809.267       135.000
# 17                  Valladolid    315.522       197.000
# 18                      Bilbao    353.187        41.000
# 19                    Zaragoza    675.121       974.000

# %% [markdown]
# ### 2.4 **Regimen** viviendas

# %%
df_regimen = pd.read_csv("files/datos_para_almacenar/Regimen.csv", sep=";")

# %%
df_regimen.columns
# Out:
# Index(['Unnamed: 0', 'Municipio', 'En alquiler', 'En propiedad',
#        'Otro régimen de tenencia', 'Total (régimen de tenencia)', '%propiedad',
#        '%alquiler', 'Proporcion Propiedad/Alquiler'],
#       dtype='object')

# %%
f.comprobar_municipio(df_regimen)

# %%
set(df_regimen['Municipio'].to_list())
# Out:
# {'A Coruña',
#  'Alacant/Alicante',
#  'Barcelona',
#  'Bilbao',
#  'Córdoba',
#  'Elche/Elx',
#  'Gijón',
#  'Granada',
#  'Las Palmas de Gran Canaria',
#  'L´Hospitalet de Llobregat',
#  'Madrid',
#  'Murcia',
#  'Málaga',
#  'Palma',
#  'Sevilla',
#  'Valencia',
#  'Valladolid',
#  'Vigo',
#  'Vitoria-Gasteiz',
#  'Zaragoza'}

# %%
df_regimen = df_regimen.drop('Unnamed: 0', axis = 1)

# %%
df_regimen
# Out:
#                      Municipio  En alquiler  En propiedad  \
# 0             Alacant/Alicante        21801        104009
# 1                    Barcelona       208468        409684
# 2                       Bilbao        21483        122697
# 3                     A Coruña        24679         69246
# 4                      Córdoba        13264        102031
# 5                    Elche/Elx        10843         72774
# 6                        Gijón        18553         90297
# 7                      Granada        18166         70361
# 8    L´Hospitalet de Llobregat        27916         66941
# 9                       Madrid       317766        927975
# 10                      Murcia        26137        121850
# 11                      Málaga        29366        174332
# 12                       Palma        39403        104815
# 13  Las Palmas de Gran Canaria        31685         94443
# 14                     Sevilla        37015        210473
# 15                  Valladolid        18622         96543
# 16                    Valencia        55865        242186
# 17                        Vigo        22106         81984
# 18             Vitoria-Gasteiz        16237         88571
# 19                    Zaragoza        50140        213969
#
#     Otro régimen de tenencia  Total (régimen de tenencia)  %propiedad  \
# 0                      10054                       135864   76.553760
# 1                      53025                       671177   61.039636
# 2                       5281                       149461   82.092987
# 3                      10712                       104637   66.177356
# 4                       7373                       122668   83.176542
# 5                       4881                        88498   82.232367
# 6                      11499                       120349   75.029290
# 7                       9789                        98316   71.566174
# 8                       6952                       101809   65.751554
# 9                      77114                      1322855   70.149412
# 10                     15583                       163570   74.494100
# 11                     14547                       218245   79.879035
# 12                     12883                       157101   66.718226
# 13                     17067                       143195   65.954119
# 14                     19100                       266588   78.950665
# 15                     12020                       127185   75.907536
# 16                     25120                       323171   74.940511
# 17                      9992                       114082   71.864098
# 18                      2357                       107165   82.649186
# 19                     15945                       280054   76.402765
#
#     %alquiler  Proporcion Propiedad/Alquiler
# 0   16.046193                       4.770836
# 1   31.060063                       1.965213
# 2   14.373649                       5.711353
# 3   23.585347                       2.805867
# 4   10.812926                       7.692325
# 5   12.252254                       6.711611
# 6   15.415998                       4.866976
# 7   18.477155                       3.873225
# 8   27.419973                       2.397944
# 9   24.021227                       2.920309
# 10  15.979092                       4.661973
# 11  13.455520                       5.936525
# 12  25.081317                       2.660077
# 13  22.127169                       2.980685
# 14  13.884721                       5.686154
# 15  14.641664                       5.184352
# 16  17.286514                       4.335201
# 17  19.377290                       3.708676
# 18  15.151402                       5.454887
# 19  17.903690                       4.267431

# %% [markdown]
# ### 2.5 **Tamaño** del hogar

# %%
df_tamaño_hogar = pd.read_csv("files/datos_para_almacenar/Tamaño_del_hogar.csv", sep=";")

# %%
df_tamaño_hogar = df_tamaño_hogar.drop('Unnamed: 0', axis=1)

# %%
f.comprobar_municipio(df_tamaño_hogar)

# %%
len(df_tamaño_hogar['Municipio'].to_list())
# Out:
# 20

# %%
df_tamaño_hogar
# Out:
#                      Municipio  1 persona  2 personas  3 personas  4 personas  \
# 0             Alacant/Alicante     39.536      37.976      27.155      21.375
# 1                    Barcelona    207.973     205.174     126.877      89.495
# 2                       Bilbao     47.407      47.145      28.826      19.589
# 3                     A Coruña     32.234      32.136      21.498      13.961
# 4                      Córdoba     31.242      33.205      25.885      23.487
# 5                    Elche/Elx     20.773      24.444      19.225      16.947
# 6                        Gijón     38.928      39.375      24.710      13.156
# 7                      Granada     33.549      27.223      17.464      13.384
# 8    L´Hospitalet de Llobregat     24.350      31.953      21.324      15.227
# 9                       Madrid    397.447     380.686     251.859     190.474
# 10                      Murcia     37.959      40.165      33.960      32.762
# 11                      Málaga     54.869      58.621      46.385      39.436
# 12                       Palma     38.296      43.849      33.830      25.061
# 13  Las Palmas de Gran Canaria     36.913      38.672      31.725      22.133
# 14                     Sevilla     71.162      73.909      54.457      47.003
# 15                  Valladolid     39.631      39.140      25.488      16.863
# 16                    Valencia     96.493      93.169      64.611      48.242
# 17                        Vigo     29.871      32.045      24.834      18.390
# 18             Vitoria-Gasteiz     33.223      33.280      19.913      15.690
# 19                    Zaragoza     80.672      84.237      57.506      42.713
#
#     5 o más personas
# 0              9.822
# 1             41.658
# 2              6.494
# 3              4.808
# 4              8.849
# 5              7.109
# 6              4.180
# 7              6.696
# 8              8.955
# 9            102.389
# 10            18.724
# 11            18.934
# 12            16.065
# 13            13.752
# 14            20.057
# 15             6.063
# 16            20.656
# 17             8.942
# 18             5.059
# 19            14.926

# %%
df_tamaño_hogar.dtypes
# Out:
# Municipio            object
# 1 persona           float64
# 2 personas          float64
# 3 personas          float64
# 4 personas          float64
# 5 o más personas    float64
# dtype: object

# %% [markdown]
# ### 2.6 **Número** de viviendas **turísticas**

# %%
df_turismo = pd.read_csv("../src/files/datos_para_almacenar/turismo.csv", sep=";")

# %%
df_turismo = df_turismo.drop("Unnamed: 0", axis = 1)

# %%
df_turismo
# Out:
#     Turismo 2024                   Municipio
# 0          177.0             Vitoria-Gasteiz
# 1         3589.0            Alacant/Alicante
# 2          760.0                   Elche/Elx
# 3         1023.0                       Palma
# 4         8842.0                   Barcelona
# 5          874.0   L´Hospitalet de Llobregat
# 6         1981.0                     Córdoba
# 7          847.0                    A Coruña
# 8         2622.0                     Granada
# 9        16100.0                      Madrid
# 10        7038.0                      Málaga
# 11         984.0                      Murcia
# 12        1427.0                       Gijón
# 13        2634.0  Las Palmas de Gran Canaria
# 14        1324.0                        Vigo
# 15        6171.0                     Sevilla
# 16        6769.0                    Valencia
# 17         330.0                  Valladolid
# 18        1134.0                      Bilbao
# 19         934.0                    Zaragoza

# %%
df_turismo[df_turismo['Municipio'].isin( municipios_top_20)]
# Out:
#     Turismo 2024                   Municipio
# 0          177.0             Vitoria-Gasteiz
# 1         3589.0            Alacant/Alicante
# 2          760.0                   Elche/Elx
# 3         1023.0                       Palma
# 4         8842.0                   Barcelona
# 5          874.0   L´Hospitalet de Llobregat
# 6         1981.0                     Córdoba
# 7          847.0                    A Coruña
# 8         2622.0                     Granada
# 9        16100.0                      Madrid
# 10        7038.0                      Málaga
# 11         984.0                      Murcia
# 12        1427.0                       Gijón
# 13        2634.0  Las Palmas de Gran Canaria
# 14        1324.0                        Vigo
# 15        6171.0                     Sevilla
# 16        6769.0                    Valencia
# 17         330.0                  Valladolid
# 18        1134.0                      Bilbao
# 19         934.0                    Zaragoza

# %% [markdown]
# ### 2.6 Tamaño

# %%
df_tamaño = pd.read_csv("../src/files/datos_para_almacenar/Tamaño.csv", sep=";")

# %%
df_tamaño = df_tamaño.drop(columns="Unnamed: 0")

# %%
df_tamaño
# Out:
#                      Municipio  total_superficie  menos_de_60m2  \
# 0              Vitoria-Gasteiz            119853          13501
# 1             Alacant/Alicante            187658          37608
# 2                    Elche/Elx            116080          17738
# 3                        Palma            186482          45228
# 4                    Barcelona            808751         395237
# 5    L´Hospitalet de Llobregat            110488          79438
# 6                      Córdoba            155400          41373
# 7                     A Coruña            136205          40341
# 8                      Granada            141257          23167
# 9                       Madrid           1533221         724030
# 10                      Málaga            261857          73569
# 11                      Murcia            219740          36158
# 12                       Gijón            148955          46097
# 13  Las Palmas de Gran Canaria            175181          49264
# 14                        Vigo            144293          36389
# 15                     Sevilla            327393          99194
# 16                    Valencia            414988          89560
# 17                  Valladolid            159363          40016
# 18                      Bilbao            165685          38972
# 19                    Zaragoza            338961         117443
#
#     entre_61_y_105m2  mas_de_106m2  %menos_de_60m2  %entre_61_y_105m2  \
# 0              92161         14191       11.264633          76.895030
# 1             119585         28691       20.040712          63.724968
# 2              73758         24435       15.280841          63.540662
# 3             105354         34841       24.253279          56.495533
# 4             332921         64688       48.870048          41.164833
# 5              29218          1321       71.897401          26.444501
# 6              86848         26825       26.623552          55.886744
# 7              82693         12987       29.617855          60.712162
# 8              88612         29082       16.400603          62.731050
# 9             660976        141824       47.222807          43.110289
# 10            148376         38981       28.095105          56.662988
# 11            133309         49178       16.454901          60.666697
# 12             90908         11792       30.946930          61.030513
# 13             89351         29221       28.121771          51.004961
# 14             79500         26143       25.218826          55.096228
# 15            182780         42836       30.298143          55.828927
# 16            265371         58119       21.581347          63.946668
# 17            102536         16623       25.109969          64.341158
# 18            105838         20875       23.521743          63.879048
# 19            187534         33641       34.647939          55.326129
#
#     %mas_de_106m2
# 0       11.840338
# 1       15.288983
# 2       21.050138
# 3       18.683305
# 4        7.998506
# 5        1.195605
# 6       17.261905
# 7        9.534892
# 8       20.588006
# 9        9.250069
# 10      14.886369
# 11      22.380086
# 12       7.916485
# 13      16.680462
# 14      18.117996
# 15      13.083969
# 16      14.004983
# 17      10.430903
# 18      12.599209
# 19       9.924741

# %% [markdown]
# ### 2. Unión de datos

# %%
df_final = pd.merge(df_ciudades1, df_tamaño_hogar, on="Municipio", how ="inner")

# %%
f.comprobar_municipio(df_final)

# %%
df_final = pd.merge(df_final, df_m2_municipio, on="Municipio", how ="inner")

# %%
df_final = pd.merge(df_final, df_anos, on="Municipio", how ="inner")

# %%
df_final = pd.merge(df_final, df_afiliados, on="Municipio", how ="inner")

# %%
df_final = pd.merge(df_final, df_turismo, on="Municipio", how ="inner")

# %%
df_final = pd.merge(df_final, df_regimen, on="Municipio", how ="inner")

# %%
df_final = pd.merge(df_final, df_tamaño, on="Municipio", how ="inner")

# %%
len(set(df_final['Municipio'].to_list()))
# Out:
# 20

# %%
df_final.columns
# Out:
# Index(['Vivienda', 'Precio (€)', 'Numero habitaciones',
#        'Metros cuadrados (m²)', 'Municipio', 'Zona', 'Barrio', 'Garaje',
#        'Regimen', 'Planta', 'Interior/Exterior', 'Ascensor', '1 persona',
#        '2 personas', '3 personas', '4 personas', '5 o más personas',
#        'Población', 'm2_municipio', 'Total viviendas en municipio',
#        'Total Antes de 1900', 'Total De 1900 a 1920', 'Total De 1921 a 1940',
#        'Total De 1941 a 1950', 'Total De 2011 a 2020', 'Total No consta',
#        'Vivienda principal Total', 'Vivienda no principal Total',
#        'Total De 1951 a 1970', 'Total De 1971 a 1990', 'Total De 1991 a 2010',
#        'reg_autonomos', 'reg_general', 'total', 'Turismo 2024', 'En alquiler',
#        'En propiedad', 'Otro régimen de tenencia',
#        'Total (régimen de tenencia)', '%propiedad', '%alquiler',
#        'Proporcion Propiedad/Alquiler', 'total_superficie', 'menos_de_60m2',
#        'entre_61_y_105m2', 'mas_de_106m2', '%menos_de_60m2',
#        '%entre_61_y_105m2', '%mas_de_106m2'],
#       dtype='object')

# %%
df_final.rename(columns={'total': 'Total afiliados',
                 'Total (régimen de tenencia)': 'Total viviendas'}, inplace= True)

# %%
df_final.drop(columns='Total viviendas en municipio', inplace=True)

# %%
df_final.drop(columns=['Vivienda principal Total', 'Vivienda no principal Total'], inplace=True)

# %%
df_final
# Out:
#                                                Vivienda  Precio (€)  \
# 0                            Piso en San Isidro, Madrid      245000
# 1     Piso en calle de Pablo Montesinos, San Isidro,...      240000
# 2     Piso en calle Soldado José María Rey, San Isid...      199000
# 3            Piso en calle Alcaudón, San Isidro, Madrid      237000
# 4                            Piso en San Isidro, Madrid      250000
# ...                                                 ...         ...
# 6168  Piso en avenida Pablo Picasso, 1, Zaidín, Granada         800
# 6169     Piso en avenida Barcelona, 18, Zaidín, Granada         700
# 6170                            Piso en Zaidín, Granada         850
# 6171        Piso en calle Covadonga, 6, Zaidín, Granada         800
# 6172                            Piso en Zaidín, Granada         900
#
#      Numero habitaciones  Metros cuadrados (m²) Municipio         Zona  \
# 0                      2                   65.0    Madrid  Carabanchel
# 1                      3                   79.0    Madrid  Carabanchel
# 2                      1                   88.0    Madrid  Carabanchel
# 3                      3                   67.0    Madrid  Carabanchel
# 4                      2                   73.0    Madrid  Carabanchel
# ...                  ...                    ...       ...          ...
# 6168                   3                   80.0   Granada       Zaidin
# 6169                   3                  140.0   Granada       Zaidin
# 6170                   3                   96.0   Granada       Zaidin
# 6171                   3                   70.0   Granada       Zaidin
# 6172                   3                   90.0   Granada       Zaidin
#
#           Barrio           Garaje   Regimen     Planta  ... %propiedad  \
# 0     San Isidro               No    Compra         1ª  ...  70.149412
# 1     San Isidro               No    Compra       Bajo  ...  70.149412
# 2     San Isidro               No    Compra         2ª  ...  70.149412
# 3     San Isidro               No    Compra         1ª  ...  70.149412
# 4     San Isidro               No    Compra         1ª  ...  70.149412
# ...          ...              ...       ...        ...  ...        ...
# 6168      Zaidin               No  Alquiler       Bajo  ...  71.566174
# 6169      Zaidin               No  Alquiler         9ª  ...  71.566174
# 6170      Zaidin  Garaje incluido  Alquiler       Bajo  ...  71.566174
# 6171      Zaidin               No  Alquiler         2ª  ...  71.566174
# 6172      Zaidin               No  Alquiler  Planta 1ª  ...  71.566174
#
#       %alquiler  Proporcion Propiedad/Alquiler  total_superficie  \
# 0     24.021227                       2.920309           1533221
# 1     24.021227                       2.920309           1533221
# 2     24.021227                       2.920309           1533221
# 3     24.021227                       2.920309           1533221
# 4     24.021227                       2.920309           1533221
# ...         ...                            ...               ...
# 6168  18.477155                       3.873225            141257
# 6169  18.477155                       3.873225            141257
# 6170  18.477155                       3.873225            141257
# 6171  18.477155                       3.873225            141257
# 6172  18.477155                       3.873225            141257
#
#       menos_de_60m2  entre_61_y_105m2  mas_de_106m2 %menos_de_60m2  \
# 0            724030            660976        141824      47.222807
# 1            724030            660976        141824      47.222807
# 2            724030            660976        141824      47.222807
# 3            724030            660976        141824      47.222807
# 4            724030            660976        141824      47.222807
# ...             ...               ...           ...            ...
# 6168          23167             88612         29082      16.400603
# 6169          23167             88612         29082      16.400603
# 6170          23167             88612         29082      16.400603
# 6171          23167             88612         29082      16.400603
# 6172          23167             88612         29082      16.400603
#
#       %entre_61_y_105m2  %mas_de_106m2
# 0             43.110289       9.250069
# 1             43.110289       9.250069
# 2             43.110289       9.250069
# 3             43.110289       9.250069
# 4             43.110289       9.250069
# ...                 ...            ...
# 6168          62.731050      20.588006
# 6169          62.731050      20.588006
# 6170          62.731050      20.588006
# 6171          62.731050      20.588006
# 6172          62.731050      20.588006
#
# [6173 rows x 46 columns]

# %%
set(df_final['Municipio'].to_list())
# Out:
# {'A Coruña',
#  'Alacant/Alicante',
#  'Barcelona',
#  'Bilbao',
#  'Córdoba',
#  'Elche/Elx',
#  'Gijón',
#  'Granada',
#  'Las Palmas de Gran Canaria',
#  'L´Hospitalet de Llobregat',
#  'Madrid',
#  'Murcia',
#  'Málaga',
#  'Palma',
#  'Sevilla',
#  'Valencia',
#  'Valladolid',
#  'Vigo',
#  'Vitoria-Gasteiz',
#  'Zaragoza'}

# %% [markdown]
# # 3.  Exportar datos limpios

# %%
os.makedirs("files", exist_ok=True)
df_final.to_csv("files/datos_para_almacenar/datos_limpios.csv", sep =";")

# %%
df_final
# Out:
#                                                Vivienda  Precio (€)  \
# 0                            Piso en San Isidro, Madrid      245000
# 1     Piso en calle de Pablo Montesinos, San Isidro,...      240000
# 2     Piso en calle Soldado José María Rey, San Isid...      199000
# 3            Piso en calle Alcaudón, San Isidro, Madrid      237000
# 4                            Piso en San Isidro, Madrid      250000
# ...                                                 ...         ...
# 6168  Piso en avenida Pablo Picasso, 1, Zaidín, Granada         800
# 6169     Piso en avenida Barcelona, 18, Zaidín, Granada         700
# 6170                            Piso en Zaidín, Granada         850
# 6171        Piso en calle Covadonga, 6, Zaidín, Granada         800
# 6172                            Piso en Zaidín, Granada         900
#
#      Numero habitaciones  Metros cuadrados (m²) Municipio         Zona  \
# 0                      2                   65.0    Madrid  Carabanchel
# 1                      3                   79.0    Madrid  Carabanchel
# 2                      1                   88.0    Madrid  Carabanchel
# 3                      3                   67.0    Madrid  Carabanchel
# 4                      2                   73.0    Madrid  Carabanchel
# ...                  ...                    ...       ...          ...
# 6168                   3                   80.0   Granada       Zaidin
# 6169                   3                  140.0   Granada       Zaidin
# 6170                   3                   96.0   Granada       Zaidin
# 6171                   3                   70.0   Granada       Zaidin
# 6172                   3                   90.0   Granada       Zaidin
#
#           Barrio           Garaje   Regimen     Planta  ... %propiedad  \
# 0     San Isidro               No    Compra         1ª  ...  70.149412
# 1     San Isidro               No    Compra       Bajo  ...  70.149412
# 2     San Isidro               No    Compra         2ª  ...  70.149412
# 3     San Isidro               No    Compra         1ª  ...  70.149412
# 4     San Isidro               No    Compra         1ª  ...  70.149412
# ...          ...              ...       ...        ...  ...        ...
# 6168      Zaidin               No  Alquiler       Bajo  ...  71.566174
# 6169      Zaidin               No  Alquiler         9ª  ...  71.566174
# 6170      Zaidin  Garaje incluido  Alquiler       Bajo  ...  71.566174
# 6171      Zaidin               No  Alquiler         2ª  ...  71.566174
# 6172      Zaidin               No  Alquiler  Planta 1ª  ...  71.566174
#
#       %alquiler  Proporcion Propiedad/Alquiler  total_superficie  \
# 0     24.021227                       2.920309           1533221
# 1     24.021227                       2.920309           1533221
# 2     24.021227                       2.920309           1533221
# 3     24.021227                       2.920309           1533221
# 4     24.021227                       2.920309           1533221
# ...         ...                            ...               ...
# 6168  18.477155                       3.873225            141257
# 6169  18.477155                       3.873225            141257
# 6170  18.477155                       3.873225            141257
# 6171  18.477155                       3.873225            141257
# 6172  18.477155                       3.873225            141257
#
#       menos_de_60m2  entre_61_y_105m2  mas_de_106m2 %menos_de_60m2  \
# 0            724030            660976        141824      47.222807
# 1            724030            660976        141824      47.222807
# 2            724030            660976        141824      47.222807
# 3            724030            660976        141824      47.222807
# 4            724030            660976        141824      47.222807
# ...             ...               ...           ...            ...
# 6168          23167             88612         29082      16.400603
# 6169          23167             88612         29082      16.400603
# 6170          23167             88612         29082      16.400603
# 6171          23167             88612         29082      16.400603
# 6172          23167             88612         29082      16.400603
#
#       %entre_61_y_105m2  %mas_de_106m2
# 0             43.110289       9.250069
# 1             43.110289       9.250069
# 2             43.110289       9.250069
# 3             43.110289       9.250069
# 4             43.110289       9.250069
# ...                 ...            ...
# 6168          62.731050      20.588006
# 6169          62.731050      20.588006
# 6170          62.731050      20.588006
# 6171          62.731050      20.588006
# 6172          62.731050      20.588006
#
# [6173 rows x 46 columns]
