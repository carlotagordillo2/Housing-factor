# %%
import pandas as pd

# %% [markdown]
# # 1. Lectura datos

# %%
df_vivienda = pd.read_csv("../data/datos_limpios.csv", sep=";")

# %%
df_vivienda
# Out:
#       Unnamed: 0                                           Vivienda  \
# 0              0                         Piso en San Isidro, Madrid
# 1              1  Piso en calle de Pablo Montesinos, San Isidro,...
# 2              2  Piso en calle Soldado José María Rey, San Isid...
# 3              3         Piso en calle Alcaudón, San Isidro, Madrid
# 4              4                         Piso en San Isidro, Madrid
# ...          ...                                                ...
# 6168        1644             Piso en Laos, 5, Emilio Lemos, Sevilla
# 6169        1645             Piso en Laos, 5, Emilio Lemos, Sevilla
# 6170        1646             Piso en Laos, 5, Emilio Lemos, Sevilla
# 6171        1647             Piso en Laos, 5, Emilio Lemos, Sevilla
# 6172        1648   Piso en calle Pakistán, 5, Emilio Lemos, Sevilla
#
#       Precio (€)  Numero habitaciones  Metros cuadrados (m²)   Ciudad  \
# 0         245000                    2                   65.0   Madrid
# ...
